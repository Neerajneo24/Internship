# %% [markdown]
# # Project Name: Image Scraping and Classification Project

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\naren kumar\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\naren kumar\appdata\roaming\python\python39\site-packages (from opencv-python) (1.23.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)

# %%
pip install Keras
# Out:
# Requirement already satisfied: Keras in c:\users\naren kumar\appdata\roaming\python\python39\site-packages (2.10.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)

# %%
pip install tensorflow --ignore-installed --user
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.10.0-cp39-cp39-win_amd64.whl (455.9 MB)
# Collecting setuptools
#   Using cached setuptools-65.5.1-py3-none-any.whl (1.2 MB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
# Collecting tensorboard<2.11,>=2.10
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.50.0-cp39-cp39-win_amd64.whl (3.7 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting keras<2.11,>=2.10.0
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Collecting six>=1.12.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp39-cp39-win_amd64.whl (35 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.1.0-py3-none-any.whl (5.8 kB)
# Collecting packaging
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.7.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting numpy>=1.20
#   Using cached numpy-1.23.4-cp39-cp39-win_amd64.whl (14.7 MB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.14.1-py2.py3-none-any.whl (175 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.10.0-py3-none-any.whl (6.2 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.9.24-py3-none-any.whl (161 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Installing collected packages: urllib3, pyasn1, idna, charset-normalizer, certifi, zipp, six, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, MarkupSafe, importlib-metadata, google-auth, wheel, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, setuptools, pyparsing, protobuf, numpy, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, packaging, opt-einsum, libclang, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed MarkupSafe-2.1.1 absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 certifi-2022.9.24 charset-normalizer-2.1.1 flatbuffers-22.10.26 gast-0.4.0 google-auth-2.14.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.50.0 h5py-3.7.0 idna-3.4 importlib-metadata-5.0.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 numpy-1.23.4 oauthlib-3.2.2 opt-einsum-3.3.0 packaging-21.3 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 setuptools-65.5.1 six-1.16.0 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.1.0 typing-extensions-4.4.0 urllib3-1.26.12 werkzeug-2.2.2 wheel-0.38.4 wrapt-1.14.1 zipp-3.10.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
#   WARNING: The script normalizer.exe is installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wheel.exe is installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.4 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.23.4 which is incompatible.
# jupyter-server 1.13.5 requires pywinpty<2; os_name == "nt", but you have pywinpty 2.0.2 which is incompatible.
# google-cloud-storage 1.31.0 requires google-auth<2.0dev,>=1.11.0, but you have google-auth 2.14.1 which is incompatible.
# google-cloud-core 1.7.1 requires google-auth<2.0dev,>=1.24.0, but you have google-auth 2.14.1 which is incompatible.
# google-api-core 1.25.1 requires google-auth<2.0dev,>=1.21.1, but you have google-auth 2.14.1 which is incompatible.
# astroid 2.6.6 requires wrapt<1.13,>=1.11, but you have wrapt 1.14.1 which is incompatible.
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -4fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -3fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0fi (c:\users\naren kumar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\naren kumar\anaconda3\lib\site-packages)

# %%
conda install -c conda-forge tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# usage: conda-script.py [-h] [-V] command ...
# conda-script.py: error: unrecognized arguments: tensorflow

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import pandas as pd


from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
from keras.callbacks import TensorBoard, ModelCheckpoint,EarlyStopping


from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications.mobilenet import MobileNet

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
from glob import glob
#import matplotlib.pyplot 

from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# C:\Users\Naren Kumar\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Model Building

# %%
Train_data_dir=r'IMAGES'
validation_data_dir=r'IMAGES'

# %%
# Number of classes in the training folder
file = os.listdir(r'IMAGES')
file
# Out:
# ['Jeans (men)', 'Sarees (women)', 'Trousers (men)']

# %%
# getting some of the scrapped images from each category
import matplotlib.image as mpimg
Jeans_train=r'IMAGES/Jeans (men)'
Saree_train=r'IMAGES/Sarees (women)'
Trouser_train=r'IMAGES/Trousers (men)'


Dir_train=[Jeans_train, Saree_train, Trouser_train]
for dirs in Dir_train:
    k=os.listdir(dirs)
    for i in k[:2]:
        img=mpimg.imread('{}/{}'.format(dirs,i))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

# %%
# Defining Dimensions for the image to be input and then loading the images
input_shape=(576,576,3)
img_width=576
img_height=576
nb_train_samples=179
nb_validation_samples=20
batch_size=8
epoch=150

# %%
# Training Data Generator( Data Augmentation on Training Images)

Train_generator_augmented=ImageDataGenerator(rescale=1./255,
                                             zoom_range=0.2,
                                             rotation_range=30,
                                             horizontal_flip=True)
Train_generator=Train_generator_augmented.flow_from_directory(Train_data_dir,
                                                              target_size=(img_width,img_height),
                                                              batch_size=batch_size, 
                                                              class_mode='categorical')

# Validation Data Generator
Data_gen=ImageDataGenerator(rescale=1./255)
validation_generator=Data_gen.flow_from_directory(validation_data_dir,
                                                  target_size=(img_width,img_height),
                                                  batch_size=batch_size, 
                                                  class_mode='categorical')
# Out:
# Found 1500 images belonging to 3 classes.
# Found 1500 images belonging to 3 classes.

# %%
# Creating the model
model=Sequential()

# First convolution layer
model.add(Conv2D(32,(3,3),input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Second convolution layer
model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Third convolution layer
model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Fourth convolution layer
model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('softmax'))

print(model.summary())

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 574, 574, 32)      896
#
#  activation (Activation)     (None, 574, 574, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 287, 287, 32)     0
#  )
#
#  dropout (Dropout)           (None, 287, 287, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 285, 285, 32)      9248
#
#  activation_1 (Activation)   (None, 285, 285, 32)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 142, 142, 32)     0
#  2D)
#
#  dropout_1 (Dropout)         (None, 142, 142, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 140, 140, 64)      18496
#
#  activation_2 (Activation)   (None, 140, 140, 64)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 70, 70, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 70, 70, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 68, 68, 64)        36928
#
#  activation_3 (Activation)   (None, 68, 68, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 34, 34, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 34, 34, 64)        0
#
#  flatten (Flatten)           (None, 73984)             0
#
#  dense (Dense)               (None, 128)               9470080
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
#  activation_5 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 9,536,035
# Trainable params: 9,536,035
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Defining Early stopping and Model check point
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
MC = ModelCheckpoint('best.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
# Fitting the Training Data
history = model.fit_generator(
    Train_generator, 
    epochs=epoch,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples//batch_size,
    steps_per_epoch=nb_train_samples//batch_size,
    callbacks=[ES,MC])
# Out:
# C:\Users\Naren Kumar\AppData\Local\Temp\ipykernel_13320\2321492758.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/150
# 22/22 [==============================] - ETA: 0s - loss: 2.2199 - accuracy: 0.3352
# Epoch 1: val_accuracy improved from -inf to 0.31250, saving model to best.h5
# 22/22 [==============================] - 40s 2s/step - loss: 2.2199 - accuracy: 0.3352 - val_loss: 1.0991 - val_accuracy: 0.3125
# Epoch 2/150
# 22/22 [==============================] - ETA: 0s - loss: 1.0988 - accuracy: 0.3523
# Epoch 2: val_accuracy did not improve from 0.31250
# 22/22 [==============================] - 39s 2s/step - loss: 1.0988 - accuracy: 0.3523 - val_loss: 1.1007 - val_accuracy: 0.1875
# Epoch 3/150
# 22/22 [==============================] - ETA: 0s - loss: 1.0988 - accuracy: 0.3239
# Epoch 3: val_accuracy did not improve from 0.31250
# 22/22 [==============================] - 39s 2s/step - loss: 1.0988 - accuracy: 0.3239 - val_loss: 1.0993 - val_accuracy: 0.2500
# Epoch 4/150
# 22/22 [==============================] - ETA: 0s - loss: 1.0993 - accuracy: 0.2898
# Epoch 4: val_accuracy did not improve from 0.31250
# 22/22 [==============================] - 37s 2s/step - loss: 1.0993 - accuracy: 0.2898 - val_loss: 1.0997 - val_accuracy: 0.2500
# Epoch 5/150
# 22/22 [==============================] - ETA: 0s - loss: 1.0980 - accuracy: 0.3750
# Epoch 5: val_accuracy did not improve from 0.31250
# 22/22 [==============================] - 42s 2s/step - loss: 1.0980 - accuracy: 0.3750 - val_loss: 1.1026 - val_accuracy: 0.1250
# Epoch 6/150
# 22/22 [==============================] - ETA: 0s - loss: 1.0903 - accuracy: 0.3977
# Epoch 6: val_accuracy improved from 0.31250 to 0.50000, saving model to best.h5
# 22/22 [==============================] - 63s 3s/step - loss: 1.0903 - accuracy: 0.3977 - val_loss: 1.0765 - val_accuracy: 0.5000
# Epoch 7/150
# 22/22 [==============================] - ETA: 0s - loss: 1.0266 - accuracy: 0.5114
# Epoch 7: val_accuracy improved from 0.50000 to 0.56250, saving model to best.h5
# 22/22 [==============================] - 61s 3s/step - loss: 1.0266 - accuracy: 0.5114 - val_loss: 1.0364 - val_accuracy: 0.5625
# Epoch 8/150
# 22/22 [==============================] - ETA: 0s - loss: 0.8342 - accuracy: 0.5682
# Epoch 8: val_accuracy improved from 0.56250 to 0.81250, saving model to best.h5
# 22/22 [==============================] - 61s 3s/step - loss: 0.8342 - accuracy: 0.5682 - val_loss: 0.7445 - val_accuracy: 0.8125
# Epoch 9/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.6761
# Epoch 9: val_accuracy did not improve from 0.81250
# 22/22 [==============================] - 62s 3s/step - loss: 0.6334 - accuracy: 0.6761 - val_loss: 1.1004 - val_accuracy: 0.3125
# Epoch 10/150
# 22/22 [==============================] - ETA: 0s - loss: 0.7203 - accuracy: 0.6420
# Epoch 10: val_accuracy did not improve from 0.81250
# 22/22 [==============================] - 62s 3s/step - loss: 0.7203 - accuracy: 0.6420 - val_loss: 1.0551 - val_accuracy: 0.6875
# Epoch 11/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6522 - accuracy: 0.6989
# Epoch 11: val_accuracy did not improve from 0.81250
# 22/22 [==============================] - 62s 3s/step - loss: 0.6522 - accuracy: 0.6989 - val_loss: 0.7629 - val_accuracy: 0.5000
# Epoch 12/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5304 - accuracy: 0.6761
# Epoch 12: val_accuracy did not improve from 0.81250
# 22/22 [==============================] - 62s 3s/step - loss: 0.5304 - accuracy: 0.6761 - val_loss: 1.0166 - val_accuracy: 0.6250
# Epoch 13/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6100 - accuracy: 0.6250
# Epoch 13: val_accuracy did not improve from 0.81250
# 22/22 [==============================] - 62s 3s/step - loss: 0.6100 - accuracy: 0.6250 - val_loss: 1.0011 - val_accuracy: 0.6875
# Epoch 14/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6379 - accuracy: 0.6307
# Epoch 14: val_accuracy improved from 0.81250 to 0.87500, saving model to best.h5
# 22/22 [==============================] - 62s 3s/step - loss: 0.6379 - accuracy: 0.6307 - val_loss: 0.4275 - val_accuracy: 0.8750
# Epoch 15/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.6136
# Epoch 15: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 62s 3s/step - loss: 0.6680 - accuracy: 0.6136 - val_loss: 0.9896 - val_accuracy: 0.4375
# Epoch 16/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5890 - accuracy: 0.6989
# Epoch 16: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 62s 3s/step - loss: 0.5890 - accuracy: 0.6989 - val_loss: 0.4628 - val_accuracy: 0.8750
# Epoch 17/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5676 - accuracy: 0.6307
# Epoch 17: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 62s 3s/step - loss: 0.5676 - accuracy: 0.6307 - val_loss: 0.9557 - val_accuracy: 0.5625
# Epoch 18/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5085 - accuracy: 0.6932
# Epoch 18: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 61s 3s/step - loss: 0.5085 - accuracy: 0.6932 - val_loss: 0.7429 - val_accuracy: 0.5000
# Epoch 19/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5261 - accuracy: 0.6875
# Epoch 19: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 61s 3s/step - loss: 0.5261 - accuracy: 0.6875 - val_loss: 0.9063 - val_accuracy: 0.5625
# Epoch 20/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5619 - accuracy: 0.6875
# Epoch 20: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 62s 3s/step - loss: 0.5619 - accuracy: 0.6875 - val_loss: 0.6667 - val_accuracy: 0.6875
# Epoch 21/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6054 - accuracy: 0.6648
# Epoch 21: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 61s 3s/step - loss: 0.6054 - accuracy: 0.6648 - val_loss: 0.7535 - val_accuracy: 0.7500
# Epoch 22/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5274 - accuracy: 0.7330
# Epoch 22: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 62s 3s/step - loss: 0.5274 - accuracy: 0.7330 - val_loss: 0.5461 - val_accuracy: 0.8125
# Epoch 23/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4874 - accuracy: 0.7330
# Epoch 23: val_accuracy did not improve from 0.87500
# 22/22 [==============================] - 61s 3s/step - loss: 0.4874 - accuracy: 0.7330 - val_loss: 0.8417 - val_accuracy: 0.3125
# Epoch 24/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.7557
# Epoch 24: val_accuracy improved from 0.87500 to 0.93750, saving model to best.h5
# 22/22 [==============================] - 61s 3s/step - loss: 0.4617 - accuracy: 0.7557 - val_loss: 0.3307 - val_accuracy: 0.9375
# Epoch 25/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.7216
# Epoch 25: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 3386s 161s/step - loss: 0.4879 - accuracy: 0.7216 - val_loss: 0.4806 - val_accuracy: 0.8125
# Epoch 26/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5117 - accuracy: 0.7500
# Epoch 26: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 41s 2s/step - loss: 0.5117 - accuracy: 0.7500 - val_loss: 0.5812 - val_accuracy: 0.9375
# Epoch 27/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.7386
# Epoch 27: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 39s 2s/step - loss: 0.5722 - accuracy: 0.7386 - val_loss: 0.7937 - val_accuracy: 0.6875
# Epoch 28/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4983 - accuracy: 0.7102
# Epoch 28: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 41s 2s/step - loss: 0.4983 - accuracy: 0.7102 - val_loss: 0.6441 - val_accuracy: 0.6875
# Epoch 29/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5569 - accuracy: 0.6989
# Epoch 29: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 43s 2s/step - loss: 0.5569 - accuracy: 0.6989 - val_loss: 0.7612 - val_accuracy: 0.6875
# Epoch 30/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.6989
# Epoch 30: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 45s 2s/step - loss: 0.5217 - accuracy: 0.6989 - val_loss: 0.8485 - val_accuracy: 0.7500
# Epoch 31/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5597 - accuracy: 0.6989
# Epoch 31: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 42s 2s/step - loss: 0.5597 - accuracy: 0.6989 - val_loss: 0.8450 - val_accuracy: 0.7500
# Epoch 32/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4746 - accuracy: 0.7386
# Epoch 32: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 44s 2s/step - loss: 0.4746 - accuracy: 0.7386 - val_loss: 0.4383 - val_accuracy: 0.7500
# Epoch 33/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4880 - accuracy: 0.7159
# Epoch 33: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 42s 2s/step - loss: 0.4880 - accuracy: 0.7159 - val_loss: 0.7179 - val_accuracy: 0.7500
# Epoch 34/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.7841
# Epoch 34: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 45s 2s/step - loss: 0.5232 - accuracy: 0.7841 - val_loss: 0.4056 - val_accuracy: 0.8750
# Epoch 35/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6110 - accuracy: 0.7443
# Epoch 35: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 45s 2s/step - loss: 0.6110 - accuracy: 0.7443 - val_loss: 0.8418 - val_accuracy: 0.6875
# Epoch 36/150
# 22/22 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.6977
# Epoch 36: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 43s 2s/step - loss: 0.6376 - accuracy: 0.6977 - val_loss: 0.7178 - val_accuracy: 0.8125
# Epoch 37/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7386
# Epoch 37: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 45s 2s/step - loss: 0.5550 - accuracy: 0.7386 - val_loss: 0.6850 - val_accuracy: 0.8125
# Epoch 38/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4834 - accuracy: 0.7727
# Epoch 38: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 45s 2s/step - loss: 0.4834 - accuracy: 0.7727 - val_loss: 0.6568 - val_accuracy: 0.8125
# Epoch 39/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5623 - accuracy: 0.6932
# Epoch 39: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 46s 2s/step - loss: 0.5623 - accuracy: 0.6932 - val_loss: 0.8398 - val_accuracy: 0.8750
# Epoch 40/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8068
# Epoch 40: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 42s 2s/step - loss: 0.4457 - accuracy: 0.8068 - val_loss: 0.5434 - val_accuracy: 0.8125
# Epoch 41/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.7727
# Epoch 41: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 40s 2s/step - loss: 0.5492 - accuracy: 0.7727 - val_loss: 1.0025 - val_accuracy: 0.7500
# Epoch 42/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.7273
# Epoch 42: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 41s 2s/step - loss: 0.5239 - accuracy: 0.7273 - val_loss: 0.5897 - val_accuracy: 0.6875
# Epoch 43/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.7330
# Epoch 43: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 40s 2s/step - loss: 0.4729 - accuracy: 0.7330 - val_loss: 0.6249 - val_accuracy: 0.8750
# Epoch 44/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5458 - accuracy: 0.7159
# Epoch 44: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 41s 2s/step - loss: 0.5458 - accuracy: 0.7159 - val_loss: 0.6352 - val_accuracy: 0.8125
# Epoch 45/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4497 - accuracy: 0.7557
# Epoch 45: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 40s 2s/step - loss: 0.4497 - accuracy: 0.7557 - val_loss: 0.4254 - val_accuracy: 0.8125
# Epoch 46/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.7841
# Epoch 46: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 43s 2s/step - loss: 0.4804 - accuracy: 0.7841 - val_loss: 0.5895 - val_accuracy: 0.6875
# Epoch 47/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4596 - accuracy: 0.7841
# Epoch 47: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 41s 2s/step - loss: 0.4596 - accuracy: 0.7841 - val_loss: 0.6334 - val_accuracy: 0.7500
# Epoch 48/150
# 22/22 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.8011
# Epoch 48: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 40s 2s/step - loss: 0.3695 - accuracy: 0.8011 - val_loss: 0.4077 - val_accuracy: 0.8125
# Epoch 49/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7330
# Epoch 49: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 42s 2s/step - loss: 0.5443 - accuracy: 0.7330 - val_loss: 0.6668 - val_accuracy: 0.7500
# Epoch 50/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.7386
# Epoch 50: val_accuracy did not improve from 0.93750
# 22/22 [==============================] - 42s 2s/step - loss: 0.4726 - accuracy: 0.7386 - val_loss: 0.6594 - val_accuracy: 0.8125
# Epoch 51/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4710 - accuracy: 0.8011
# Epoch 51: val_accuracy improved from 0.93750 to 1.00000, saving model to best.h5
# 22/22 [==============================] - 41s 2s/step - loss: 0.4710 - accuracy: 0.8011 - val_loss: 0.4522 - val_accuracy: 1.0000
# Epoch 52/150
# 22/22 [==============================] - ETA: 0s - loss: 0.4817 - accuracy: 0.7159
# Epoch 52: val_accuracy did not improve from 1.00000
# 22/22 [==============================] - 40s 2s/step - loss: 0.4817 - accuracy: 0.7159 - val_loss: 0.7163 - val_accuracy: 0.7500
# Epoch 53/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.7727
# Epoch 53: val_accuracy did not improve from 1.00000
# 22/22 [==============================] - 42s 2s/step - loss: 0.5189 - accuracy: 0.7727 - val_loss: 1.1059 - val_accuracy: 0.6250
# Epoch 54/150
# 22/22 [==============================] - ETA: 0s - loss: 0.5740 - accuracy: 0.7273
# Epoch 54: val_accuracy did not improve from 1.00000
# 22/22 [==============================] - 42s 2s/step - loss: 0.5740 - accuracy: 0.7273 - val_loss: 0.8894 - val_accuracy: 0.5625
# Epoch 54: early stopping

# %%
# Model Evaluation
evl=model.evaluate(validation_generator,steps=1)
print("Test Loss",evl[0])
print("Test Accuracy",evl[1])
# Out:
# 1/1 [==============================] - 0s 421ms/step - loss: 0.8815 - accuracy: 0.6250
# Test Loss 0.8815035820007324
# Test Accuracy 0.625

# %%
model.save('img_model.h1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: img_model.h1\assets
# INFO:tensorflow:Assets written to: img_model.h1\assets

# %% [markdown]
# # Prediction

# %%
from keras.models import load_model
model = load_model('img_model.h1')

# %%
#Predicted samples of the test images
test_jeans=r"IMAGES/Jeans (men)"
test_Saree=r"IMAGES/Sarees (women)"
test_trouser=r"IMAGES/Trousers (men)"

from os import listdir
Predicted_class=[]
classes=[test_jeans,test_Saree,test_trouser]
for test_dir in classes:
    for i in listdir(test_dir):
        print("Input Image is:",i)
        img= image.load_img('{}/{}'.format(test_dir,i))                         
        test_image = image.load_img('{}/{}'.format(test_dir,i),target_size=(200,200))
        test_image = image.img_to_array(test_image)
        plt.imshow(img)
        plt.axis('off')
        plt.show()
        test_image = np.expand_dims(test_image, axis=0)
        result = model.predict(test_image)
        final=np.argmax(result, axis=1)[0]
        if final==0:
            print("Predicted Label is: jeans\n")
            Predicted_class.append("Jeans (men)")
        elif final==1:
            print("Predicted Label is: sarees\n")
            Predicted_class.append("Sarees (women)")
        elif final==2:
            print("Predicted Label is: trouser\n")
            Predicted_class.append("Trousers (men)")
# Out:
# Input Image is: img1.jpeg
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [31], in <cell line: 9>()
#      17 plt.show()
#      18 test_image = np.expand_dims(test_image, axis=0)
# ---> 19 result = model.predict(test_image)
#      20 final=np.argmax(result, axis=1)[0]
#      21 if final==0:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/flatten/Reshape' defined at (most recent call last):
#     File "C:\Users\Naren Kumar\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Naren Kumar\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Naren Kumar\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\Naren Kumar\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\Naren Kumar\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#       return runner(coro)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Naren Kumar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Naren Kumar\AppData\Local\Temp\ipykernel_13320\538054715.py", line 19, in <cell line: 9>
#       result = model.predict(test_image)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 2253, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 2041, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 2027, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 2015, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 1983, in predict_step
#       return self(x, training=False)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Naren Kumar\AppData\Roaming\Python\Python39\site-packages\keras\layers\reshaping\flatten.py", line 104, in call
#       return tf.reshape(inputs, flattened_shape)
# Node: 'sequential/flatten/Reshape'
# Input to reshape is a tensor with 6400 values, but the requested shape requires a multiple of 73984
# 	 [[{{node sequential/flatten/Reshape}}]] [Op:__inference_predict_function_104952]
